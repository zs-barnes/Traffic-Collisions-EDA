# %% [markdown]
# #### EDA and Visualization Final Project: Data Prep and Analysis
# ###### Zachary Barnes and Bing Wang

# %% [markdown]
# ##### Housekeeping

# %%
# Load Python libraries
import os
import numpy as np
import pandas as pd

# Run R code adjacent to Python code
# %load_ext rpy2.ipython

# Load ggplot R library
# %R library(ggplot2)
# %R library(scales)

# Avoid kernal death
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ##### Read in and organize data (Collisions and Victims datasets, from TIMS)

# %%
c = pd.read_csv("Collisions.csv")

# Keep only relevant columns
c = c[['CASE_ID','COLLISION_DATE','INTERSECTION','COLLISION_SEVERITY',
        'LIGHTING','LOCATION_TYPE','MVIW','TYPE_OF_COLLISION',
        'WEATHER_1','LATITUDE','LONGITUDE','PRIMARY_RD',
        'SECONDARY_RD','POINT_X','POINT_Y']]
c.sample(5)
# Out:
#        CASE_ID COLLISION_DATE INTERSECTION  COLLISION_SEVERITY LIGHTING  \
# 1626   8688829     2018-07-23            Y                   3        C
# 2121   8649552     2018-06-27            N                   3        A
# 2178   8637038     2018-05-30            Y                   4        C
# 130   90683244     2018-03-05            N                   4        A
# 479    8777092     2018-12-07            N                   4        A
#
#      LOCATION_TYPE MVIW TYPE_OF_COLLISION WEATHER_1  LATITUDE  LONGITUDE  \
# 1626           NaN    -                 H         A       NaN        NaN
# 2121           NaN    C                 A         A       NaN        NaN
# 2178           NaN    G                 D         A       NaN        NaN
# 130            NaN    C                 C         A  37.72496 -122.40151
# 479            NaN    B                 D         A       NaN        NaN
#
#          PRIMARY_RD                      SECONDARY_RD     POINT_X    POINT_Y
# 1626  SACRAMENTO ST                         LARKIN ST -122.419240  37.791710
# 2121    COLUMBUS AV                         TAYLOR ST -122.414880  37.803550
# 2178    VAN NESS AV                     MCALLISTER ST -122.420330  37.780050
# 130       US-101 NB  N. RD. EDGE OF THE PAUL AVE. U/C -122.401571  37.724939
# 479   SACRAMENTO ST                       FRANKLIN ST -122.424160  37.791090

# %%
v = pd.read_csv('Victims.csv')

# Keep only relevant columns
v = v[['CASE_ID','VICTIM_DEGREE_OF_INJURY','VICTIM_ROLE','VICTIM_AGE']]
v.sample(5)
# Out:
#       CASE_ID  VICTIM_DEGREE_OF_INJURY  VICTIM_ROLE  VICTIM_AGE
# 3563  8619257                        2            3          49
# 2174  8685925                        4            2          30
# 3462  8620702                        4            1          23
# 116   8777397                        4            2          15
# 3698  8603104                        4            2          41

# %%
# Merge Collisions and Victims datasets
cv = pd.merge(c, v, how='left', on='CASE_ID')
cv.sample(5)
# Out:
#       CASE_ID COLLISION_DATE INTERSECTION  COLLISION_SEVERITY LIGHTING  \
# 4526  8587685     2018-04-17            N                   4        A
# 767   8776919     2018-12-21            -                   4        A
# 1672  8742299     2018-10-23            Y                   4        A
# 982   8758241     2018-11-29            Y                   4        A
# 1107  8758118     2018-11-06            Y                   3        A
#
#      LOCATION_TYPE MVIW TYPE_OF_COLLISION WEATHER_1  LATITUDE  LONGITUDE  \
# 4526           NaN    C                 C         A       NaN        NaN
# 767            NaN    C                 F         A       NaN        NaN
# 1672           NaN    C                 A         A       NaN        NaN
# 982            NaN    C                 A         B       NaN        NaN
# 1107           NaN    B                 G         A       NaN        NaN
#
#       PRIMARY_RD SECONDARY_RD     POINT_X    POINT_Y  VICTIM_DEGREE_OF_INJURY  \
# 4526  LINCOLN WY      29TH AV -122.488071  37.764984                        4
# 767    BRYANT ST       2ND ST -122.393630  37.783080                        4
# 1672   LAGUNA ST     ELLIS ST -122.427580  37.782980                        0
# 982       BAY ST    KEARRY ST -122.407170  37.806440                        0
# 1107  LINCOLN BL      41ST AV -122.500850  37.764410                        3
#
#       VICTIM_ROLE  VICTIM_AGE
# 4526            1          32
# 767             2          35
# 1672            2          28
# 982             2           8
# 1107            3          68

# %%
# Paul's Function to remove NaNs from columns
def fixDFcolsForR(myDF):
    for i in range(myDF.shape[1]): # for each col
        if myDF.iloc[:, i].dtype == 'O': # check if col is type object
            myDF.iloc[:, i] = myDF.iloc[:, i].astype(str) # if yes set type to string
    return myDF

# %%
# Convert NaNs to string type
cv = fixDFcolsForR(cv)
cv.sample(5)
# Out:
#       CASE_ID COLLISION_DATE INTERSECTION  COLLISION_SEVERITY LIGHTING  \
# 2045  8708780     2018-09-04            Y                   4        A
# 3862  8619276     2018-04-11            Y                   3        C
# 4123  8601444     2018-03-23            -                   3        A
# 819   8764196     2018-11-15            Y                   4        A
# 427   8777414     2018-12-08            Y                   4        C
#
#      LOCATION_TYPE MVIW TYPE_OF_COLLISION WEATHER_1  LATITUDE  LONGITUDE  \
# 2045           nan    C                 B         B       NaN        NaN
# 3862           nan    B                 G         A       NaN        NaN
# 4123           nan    B                 G         A       NaN        NaN
# 819            nan    C                 C         A       NaN        NaN
# 427            nan    C                 D         A       NaN        NaN
#
#          PRIMARY_RD  SECONDARY_RD    POINT_X    POINT_Y  \
# 2045       OFARRELL  OFARRELL 170        NaN        NaN
# 3862        25TH ST    ORANGE ALY -122.41995  37.750550
# 4123       EVANS AV      SELBY ST -122.39408  37.746181
# 819   MCALLISTER ST     LARKIN ST -122.41694  37.780500
# 427     VAN NESS AV   CHESTNUT ST -122.42478  37.802260
#
#       VICTIM_DEGREE_OF_INJURY  VICTIM_ROLE  VICTIM_AGE
# 2045                        4            1          52
# 3862                        3            3          69
# 4123                        3            3          37
# 819                         0            2          48
# 427                         0            2          25

# %%
cv12 = cv.loc[(cv['VICTIM_DEGREE_OF_INJURY'] == 1) | (cv['VICTIM_DEGREE_OF_INJURY'] == 2)]
# cv12.to_csv('victims12.csv')

# %%
d = pd.read_csv("Collisions.csv")
d.head()
# Out:
#     CASE_ID  ACCIDENT_YEAR   PROC_DATE  JURIS COLLISION_DATE  COLLISION_TIME  \
# 0  90736476           2018  2018-05-29   9335     2018-05-18             755
# 1  90736282           2018  2018-05-29   9335     2018-05-17            1215
# 2  90735985           2018  2018-05-29   9335     2018-05-28            1045
# 3  90735917           2018  2018-05-29   9335     2018-05-17            1035
# 4  90735464           2018  2018-05-28   9335     2018-05-22            1723
#
#   OFFICER_ID REPORTING_DISTRICT  DAY_OF_WEEK  CHP_SHIFT  ...  COUNT_MC_KILLED  \
# 0     022037                NaN            5          1  ...                0
# 1     022007                NaN            4          1  ...                0
# 2     018845                NaN            1          1  ...                0
# 3     022096                NaN            4          1  ...                0
# 4     018688                NaN            2          2  ...                0
#
#    COUNT_MC_INJURED  PRIMARY_RAMP  SECONDARY_RAMP  LATITUDE  LONGITUDE  \
# 0                 0             -               -  37.73747 -122.40784
# 1                 0             -               -  37.73841 -122.40775
# 2                 0             -               -  37.78522 -122.39317
# 3                 0             -               -  37.72752 -122.40259
# 4                 0             -               -  37.80830 -122.36712
#
#           COUNTY           CITY     POINT_X    POINT_Y
# 0  SAN FRANCISCO  SAN FRANCISCO -122.407801  37.737483
# 1  SAN FRANCISCO  SAN FRANCISCO         NaN        NaN
# 2  SAN FRANCISCO  SAN FRANCISCO -122.393170  37.785220
# 3  SAN FRANCISCO  SAN FRANCISCO -122.402545  37.727537
# 4  SAN FRANCISCO  SAN FRANCISCO -122.367035  37.808211
#
# [5 rows x 80 columns]

# %%
cv12.loc[(cv['CASE_ID']) == 8804185]
# Out:
#      CASE_ID COLLISION_DATE INTERSECTION  COLLISION_SEVERITY LIGHTING  \
# 349  8804185     2018-12-29            Y                   2        C
#
#     LOCATION_TYPE MVIW TYPE_OF_COLLISION WEATHER_1  LATITUDE  LONGITUDE  \
# 349           nan    C                 A         A       NaN        NaN
#
#      PRIMARY_RD SECONDARY_RD    POINT_X   POINT_Y  VICTIM_DEGREE_OF_INJURY  \
# 349  PORTOLA DR   CLIPPER ST -122.44484  37.74694                        2
#
#      VICTIM_ROLE  VICTIM_AGE
# 349            1          32
