# %% [markdown]
# #### EDA and Visualization Final Project: Data Prep and Analysis
# ###### Zachary Barnes and Bing Wang

# %% [markdown]
# ##### Housekeeping

# %%
# Load Python libraries
import os
import numpy as np
import pandas as pd

# Run R code adjacent to Python code
# %load_ext rpy2.ipython

# Load ggplot R library
# %R library(ggplot2)
# %R library(scales)

# Avoid kernal death
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# ##### Read in and organize data (Collisions and Victims datasets, from TIMS)

# %%
c = pd.read_csv("Collisions.csv")

# Keep only relevant columns
c = c[['CASE_ID','COLLISION_DATE','COLLISION_TIME','INTERSECTION','COLLISION_SEVERITY',
        'LIGHTING','LOCATION_TYPE','MVIW','TYPE_OF_COLLISION',
        'WEATHER_1','LATITUDE','LONGITUDE','PRIMARY_RD',
        'SECONDARY_RD','POINT_X','POINT_Y']]
# Convert COLLISION_TIME to hour of day
c['COLLISION_TIME'] = [int(i[:-2]) if len(i) > 2 else 0 for i in c['COLLISION_TIME'].astype(str).values]

# Add quarter column
c['QUARTER'] = c['COLLISION_DATE'].map(pd.to_datetime).dt.quarter
c.sample(5)
# Out:
#        CASE_ID COLLISION_DATE  COLLISION_TIME INTERSECTION  \
# 2872   8594583     2018-03-02               3            Y
# 1374   8708224     2018-08-17              13            Y
# 10    90735081     2018-05-19              14            N
# 3198   8555554     2018-01-07              11            Y
# 543    8764300     2018-11-14              20            N
#
#       COLLISION_SEVERITY LIGHTING LOCATION_TYPE MVIW TYPE_OF_COLLISION  \
# 2872                   4        C           NaN    B                 G
# 1374                   3        A           NaN    B                 G
# 10                     3        A           NaN    C                 C
# 3198                   3        A           NaN    A                 H
# 543                    2        C           NaN    C                 B
#
#      WEATHER_1  LATITUDE  LONGITUDE    PRIMARY_RD    SECONDARY_RD     POINT_X  \
# 2872         A       NaN        NaN        6TH ST    STEVENSON ST -122.409670
# 1374         A       NaN        NaN     SUTTER ST     BUCHANAN ST -122.429980
# 10           A  37.76509 -122.40489    US-101 N/B    17TH ST. U/C -122.404829
# 3198         B       NaN        NaN        9TH AV       IRVING ST -122.466320
# 543          A       NaN        NaN  JEFFERSON ST  LEAVENWORTH ST -122.418597
#
#         POINT_Y  QUARTER
# 2872  37.781770        1
# 1374  37.786510        3
# 10    37.765100        2
# 3198  37.764040        1
# 543   37.807861        4

# %%
v = pd.read_csv('Victims12.csv')

# Keep only relevant columns
v = v[['CASE_ID','VICTIM_DEGREE_OF_INJURY','VICTIM_ROLE','VICTIM_AGE']]
v.sample(5)
# Out:
#      CASE_ID  VICTIM_DEGREE_OF_INJURY  VICTIM_ROLE  VICTIM_AGE
# 223  8594866                        2            4          49
# 80   8716537                        2            3          37
# 37   8758252                        2            3          27
# 157  8637035                        2            4          30
# 198  8602972                        2            1          18

# %%
# Merge Collisions and Victims datasets
cv = pd.merge(c, v, how='left', on='CASE_ID')
cv.sample(5)
# Out:
#        CASE_ID COLLISION_DATE  COLLISION_TIME INTERSECTION  \
# 1792   8683720     2018-07-10              14            N
# 2221   8636978     2018-05-28              19            Y
# 75    90705946     2018-04-05              16            N
# 2237   8636956     2018-05-09              19            Y
# 1305   8716427     2018-09-14              18            Y
#
#       COLLISION_SEVERITY LIGHTING LOCATION_TYPE MVIW TYPE_OF_COLLISION  \
# 1792                   3        A           NaN    C                 D
# 2221                   3        B           NaN    C                 D
# 75                     4        A           NaN    C                 C
# 2237                   4        B           NaN    B                 G
# 1305                   3        A           NaN    B                 G
#
#      WEATHER_1  LATITUDE  LONGITUDE  PRIMARY_RD     SECONDARY_RD     POINT_X  \
# 1792         A       NaN        NaN      8TH AV       CLEMENT ST -122.466597
# 2221         A       NaN        NaN     POST ST         GOUGH ST -122.424840
# 75           B  37.74945 -122.40387  US-101 S/B  CESAR CHAVEZ ST -122.403799
# 2237         A       NaN        NaN    BEALE ST        HOWARD ST -122.394280
# 1305         A       NaN        NaN  MISSION ST           8TH ST -122.413160
#
#         POINT_Y  QUARTER  VICTIM_DEGREE_OF_INJURY  VICTIM_ROLE  VICTIM_AGE
# 1792  37.783224        3                      NaN          NaN         NaN
# 2221  37.786190        2                      NaN          NaN         NaN
# 75    37.749428        2                      NaN          NaN         NaN
# 2237  37.789920        2                      NaN          NaN         NaN
# 1305  37.777460        3                      NaN          NaN         NaN

# %%
# Paul's Function to remove NaNs from columns
def fixDFcolsForR(myDF):
    for i in range(myDF.shape[1]): # for each col
        if myDF.iloc[:, i].dtype == 'O': # check if col is type object
            myDF.iloc[:, i] = myDF.iloc[:, i].astype(str) # if yes set type to string
    return myDF

# %%
# Convert NaNs to string type
cv = fixDFcolsForR(cv)
cv.sample(5)
# Out:
#        CASE_ID COLLISION_DATE  COLLISION_TIME INTERSECTION  \
# 1021   8754667     2018-10-12               9            N
# 1472   8698198     2018-08-09              16            Y
# 3149   8572546     2018-02-28               8            Y
# 125   90683783     2018-03-07              12            N
# 2714   8597278     2018-03-26              18            Y
#
#       COLLISION_SEVERITY LIGHTING LOCATION_TYPE MVIW TYPE_OF_COLLISION  \
# 1021                   4        A           nan    B                 G
# 1472                   4        A           nan    C                 D
# 3149                   2        A           nan    G                 A
# 125                    4        A           nan    C                 C
# 2714                   4        A           nan    C                 C
#
#      WEATHER_1  LATITUDE  LONGITUDE  PRIMARY_RD  SECONDARY_RD     POINT_X  \
# 1021         A       NaN        NaN    GEARY BL       24TH AV -122.483653
# 1472         A       NaN        NaN  CONCORD ST  BRUNSWICK ST -122.442160
# 3149         A       NaN        NaN     22ND ST  TENNESSEE ST -122.389250
# 125          A  37.74354 -122.40628  US-101 S/B  FAITH ST O/C -122.406211
# 2714         A       NaN        NaN      7TH ST     HOWARD ST -122.409400
#
#         POINT_Y  QUARTER  VICTIM_DEGREE_OF_INJURY  VICTIM_ROLE  VICTIM_AGE
# 1021  37.780210        4                      NaN          NaN         NaN
# 1472  37.710920        3                      NaN          NaN         NaN
# 3149  37.757890        1                      2.0          4.0        25.0
# 125   37.743482        1                      NaN          NaN         NaN
# 2714  37.777980        1                      NaN          NaN         NaN

# %% [markdown]
# # Use Nominatim API to convert lat long to OSM ID

# %%
import requests
import json

def osmid(lat,lon):
    URL = 'https://nominatim.openstreetmap.org/reverse?format=json&lat=%s&lon=%s'
    r = requests.get(URL % (lat,lon))
    data = json.loads(r.text)
#     osm_id = data.get('osm_id','NONE')
    return data['osm_id']

# %%
import time
lat_long = cv[['POINT_Y','POINT_X','VICTIM_DEGREE_OF_INJURY']]
osm_id = list()
for i,row in lat_long.iterrows():
    if (np.isnan(row['POINT_Y']) or np.isnan(row['POINT_X'])) or np.isnan(row['VICTIM_DEGREE_OF_INJURY']):
        osm_id.append('NONE')
        continue
    else:
        time.sleep(2)
        osm_id.append(osmid(row['POINT_Y'],row['POINT_X']))
osm_series = pd.Series(osm_id)
osm_series.to_csv('osm.csv')
# Out:
# /Users/zacharybarnes/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   del sys.path[0]
