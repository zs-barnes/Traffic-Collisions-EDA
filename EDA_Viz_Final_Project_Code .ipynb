# %% [markdown]
# #### EDA and Visualization Final Project: Data Prep and Analysis
# ###### Zachary Barnes and Bing Wang

# %% [markdown]
# ##### Housekeeping

# %%
# Load Python libraries
import os
import numpy as np
import pandas as pd

# Run R code adjacent to Python code
# %load_ext rpy2.ipython

# Load ggplot R library
# %R library(ggplot2)
# %R library(scales)

# Avoid kernal death
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# ##### Read in and organize data (Collisions and Victims datasets, from TIMS)

# %%
c = pd.read_csv("Collisions.csv")

# Keep only relevant columns
c = c[['CASE_ID','COLLISION_DATE','COLLISION_TIME','INTERSECTION','COLLISION_SEVERITY',
        'LIGHTING','LOCATION_TYPE','MVIW','TYPE_OF_COLLISION',
        'WEATHER_1','LATITUDE','LONGITUDE','PRIMARY_RD',
        'SECONDARY_RD','POINT_X','POINT_Y']]
# Convert COLLISION_TIME to hour of day
c['COLLISION_TIME'] = [int(i[:-2]) if len(i) > 2 else 0 for i in c['COLLISION_TIME'].astype(str).values ]
c.sample(5)
# Out:
#       CASE_ID COLLISION_DATE  COLLISION_TIME INTERSECTION  COLLISION_SEVERITY  \
# 1147  8720169     2018-04-13              18            Y                   4
# 532   8766608     2018-11-02              16            Y                   4
# 1121  8724540     2018-09-05              12            Y                   4
# 1302  8716426     2018-09-22              22            Y                   4
# 1420  8699732     2018-08-30              18            N                   3
#
#      LIGHTING LOCATION_TYPE MVIW TYPE_OF_COLLISION WEATHER_1  LATITUDE  \
# 1147        A           NaN    C                 C         A       NaN
# 532         A           NaN    G                 D         A       NaN
# 1121        A           NaN    G                 -         A       NaN
# 1302        C           NaN    C                 D         A       NaN
# 1420        A           NaN    B                 G         A       NaN
#
#       LONGITUDE   PRIMARY_RD    SECONDARY_RD     POINT_X    POINT_Y
# 1147        NaN  GUERRERO ST         16TH ST -122.424100  37.764780
# 532         NaN    MARKET ST  MARKET ST 1133         NaN        NaN
# 1121        NaN   MISSION ST          4TH ST -122.404260  37.784520
# 1302        NaN     JONES ST         TURK ST -122.412410  37.783000
# 1420        NaN    DUBOCE AV      ELGIN PARK -122.423098  37.769833

# %%
v = pd.read_csv('Victims.csv')

# Keep only relevant columns
v = v[['CASE_ID','VICTIM_DEGREE_OF_INJURY','VICTIM_ROLE','VICTIM_AGE']]
v.sample(5)
# Out:
#        CASE_ID  VICTIM_DEGREE_OF_INJURY  VICTIM_ROLE  VICTIM_AGE
# 1578   8716490                        4            5          37
# 992    8754829                        3            2          27
# 1105   8754760                        4            1          24
# 5722  90828614                        7            2          16
# 605    8758271                        4            3          31

# %%
# Merge Collisions and Victims datasets
cv = pd.merge(c, v, how='left', on='CASE_ID')
cv.sample(5)
# Out:
#       CASE_ID COLLISION_DATE  COLLISION_TIME INTERSECTION  COLLISION_SEVERITY  \
# 3935  8619224     2018-04-11            1950            Y                   4
# 3143  8656273     2018-06-21            1153            Y                   3
# 3026  8656472     2018-06-24            1841            Y                   4
# 5290  8543882     2018-01-25            1929            Y                   4
# 2099  8705819     2018-09-05            1504            Y                   3
#
#      LIGHTING LOCATION_TYPE MVIW TYPE_OF_COLLISION WEATHER_1  LATITUDE  \
# 3935        C           NaN    G                 G         C       NaN
# 3143        A           NaN    G                 -         A       NaN
# 3026        A           NaN    C                 C         A       NaN
# 5290        C             I    C                 A         A       NaN
# 2099        A           NaN    D                 B         A       NaN
#
#       LONGITUDE   PRIMARY_RD SECONDARY_RD     POINT_X    POINT_Y  \
# 3935        NaN  CABRILLO ST      38TH AV -122.498240  37.773810
# 3143        NaN   OCTAVIA ST    HAIGHT ST -122.423930  37.772960
# 3026        NaN    FOLSOM ST      17TH ST -122.415150  37.763690
# 5290        NaN   KIRKHAM ST      19TH AV -122.476917  37.759846
# 2099        NaN      10TH ST  SHERIDAN ST -122.411870  37.772080
#
#       VICTIM_DEGREE_OF_INJURY  VICTIM_ROLE  VICTIM_AGE
# 3935                        4            4          61
# 3143                        3            4          24
# 3026                        4            2          27
# 5290                        4            1          49
# 2099                        3            1          52

# %%
# Paul's Function to remove NaNs from columns
def fixDFcolsForR(myDF):
    for i in range(myDF.shape[1]): # for each col
        if myDF.iloc[:, i].dtype == 'O': # check if col is type object
            myDF.iloc[:, i] = myDF.iloc[:, i].astype(str) # if yes set type to string
    return myDF

# %%
# Convert NaNs to string type
cv = fixDFcolsForR(cv)
cv.sample(5)
# Out:
#        CASE_ID COLLISION_DATE  COLLISION_TIME INTERSECTION  \
# 5819  90866269     2018-11-13            1735            N
# 2792   8683332     2018-07-09            1430            N
# 3504   8636928     2018-05-11            1708            Y
# 3233   8650559     2018-07-10            1430            Y
# 4547   8575269     2018-02-03            2020            Y
#
#       COLLISION_SEVERITY LIGHTING LOCATION_TYPE MVIW TYPE_OF_COLLISION  \
# 5819                   4        D           nan    C                 C
# 2792                   4        A           nan    B                 G
# 3504                   4        A           nan    G                 D
# 3233                   4        A           nan    C                 B
# 4547                   4        C           nan    B                 D
#
#      WEATHER_1  LATITUDE  LONGITUDE   PRIMARY_RD SECONDARY_RD     POINT_X  \
# 5819         A  37.72329  -122.4009   US-101 N/B     PAUL AVE -122.400902
# 2792         A       NaN        NaN       6TH ST    HOWARD ST -122.407394
# 3504         A       NaN        NaN          BAY     FILLMORE -122.436650
# 3233         A       NaN        NaN  HARRISON ST       2ND ST -122.395180
# 4547         A       NaN        NaN      EDDY ST      POLK ST -122.419180
#
#         POINT_Y  VICTIM_DEGREE_OF_INJURY  VICTIM_ROLE  VICTIM_AGE
# 5819  37.723289                        7            1          19
# 2792  37.779956                        4            3          48
# 3504  37.802700                        4            4          50
# 3233  37.784330                        4            1          43
# 4547  37.783080                        4            3          59
